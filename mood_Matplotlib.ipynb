# %% [markdown]
# Matplotlib : Visualization with Python

# %%
import matplotlib.pyplot as plt
from random import randrange, seed

# %%
randrange(0,11)
# Out:
# 8

# %%
grades_maths = []
# seed(8)

for grades in range(6):
  grades_maths.append(randrange(0,11))

grades_maths
# Out:
# [1, 5, 10, 8, 5, 9]

# %%
len(grades_maths)
# Out:
# 6

# %% [markdown]
# generating a graph :

# %%
# list(range(1,7))

x = list(range(1,7))
y = grades_maths
plt.plot(x,y, marker = 'o')
plt.title('Maths Grades Visualization')
plt.xlabel('Tests')
plt.ylabel('Grades')
plt.show()

# %% [markdown]
# `HOW I wAs Feeling THIS pAst monTH 😮

# %%
import matplotlib.pyplot as plt
mood_by_day = [6.5, 8, 7, 8.5, 4, 4.5, 7, 6, 4, 8.5, 
               8.5, 6, 7, 3, 5.5, 9, 8,
               7, 6, 5,9, 6, 7.5, 8.5,
               7, 6, 7.5 , 5, 7.5, 9]
days= list(range(1,31))
x = days 
y = mood_by_day
plt.plot(x,y, marker = 'o')
plt.title('Mood Graphic - July 2022')
plt.xlabel('Day')
plt.ylabel('Mood Scale')
plt.show()
